# %% [markdown]
# <a href="https://colab.research.google.com/github/dozhash/ai_foundation/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
# Dictionary
mydataset = {
  'cars': ["BMW", "Volvo", "Ford", "Tesla", "Ferrari", "Bugatti", "BMW"],
  'counts': [3, 7, 2, 8, 1, 9, 3]
}
# print(mydataset)

df = pd.DataFrame(mydataset)
print(df)
# Out:
#       cars  counts
# 0      BMW       3
# 1    Volvo       7
# 2     Ford       2
# 3    Tesla       8
# 4  Ferrari       1
# 5  Bugatti       9
# 6      BMW       3

# %%
# head method
df.head(3) # default 5 rows
# Out:
#     cars  counts
# 0    BMW       3
# 1  Volvo       7
# 2   Ford       2

# %%
# tail method
df.tail(-1) # default 5 rows
# Out:
#       cars  counts
# 1    Volvo       7
# 2     Ford       2
# 3    Tesla       8
# 4  Ferrari       1
# 5  Bugatti       9
# 6      BMW       3

# %%
df.shape
# Out:
# (7, 2)

# %%
df.columns
# Out:
# Index(['cars', 'counts'], dtype='object')

# %%
df.dtypes
# Out:
# cars      object
# counts     int64
# dtype: object

# %%
print(df)
# Out:
#       cars  counts
# 0      BMW       3
# 1    Volvo       7
# 2     Ford       2
# 3    Tesla       8
# 4  Ferrari       1
# 5  Bugatti       9
# 6      BMW       3

# %%
df.describe() # numerical columns only
# Out:
#          counts
# count  7.000000
# mean   4.714286
# std    3.199702
# min    1.000000
# 25%    2.500000
# 50%    3.000000
# 75%    7.500000
# max    9.000000

# %%
# iloc (integer location) method - kerakli malumotlarini tanlab olish

# df.iloc[0]
# df.iloc[1]
# df.iloc[-1]
# df.iloc[1:5]
df.iloc[2:]
# Out:
#       cars  counts
# 2     Ford       2
# 3    Tesla       8
# 4  Ferrari       1
# 5  Bugatti       9
# 6      BMW       3

# %%
# loc method - kerakli malumotlarni ma'lum bir columndan tanlab olish
df.loc[2:5, "cars"]
# Out:
# 2       Ford
# 3      Tesla
# 4    Ferrari
# 5    Bugatti
# Name: cars, dtype: object

# %%
print(df)
# Out:
#       cars  counts
# 0      BMW       3
# 1    Volvo       7
# 2     Ford       2
# 3    Tesla       8
# 4  Ferrari       1
# 5  Bugatti       9
# 6      BMW       3

# %%
df["counts"] >= 3
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6     True
# Name: counts, dtype: bool

# %%
df[df["counts"] >= 3]
# df[df["cars"] == "BMW"]
# Out:
#       cars  counts
# 0      BMW       3
# 1    Volvo       7
# 3    Tesla       8
# 5  Bugatti       9
# 6      BMW       3

# %%
# mean
a = df.mean(numeric_only=True)
b = df["counts"].mean()

print(a, "\n")
print(b, "\n")

print("======\n")
print(df.min())

print("======\n")
print(df.max())

print("======\n")
print(df.median(numeric_only=True))

print("======\n")
print(df.count())
# Out:
# counts    4.714286
# dtype: float64
#
# 4.714285714285714
#
# ...
#
# cars      BMW
# counts      1
# dtype: object
# ...
#
# cars      Volvo
# counts        9
# dtype: object
# ...
#
# counts    3.0
# dtype: float64
# ...
#
# cars      7
# counts    7
# dtype: int64

# %%
df.std(numeric_only=True)
# Out:
# counts    3.199702
# dtype: float64

# %%
dataset = {
  'cars': ["BMW", "Volvo", "Ford", None, "Ferrari", "Bugatti", None],
  'counts': [3, 7, 2, None, 8, 14, 17]
}

df_missing = pd.DataFrame(dataset)
print(df_missing)
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    Volvo     7.0
# 2     Ford     2.0
# 3     None     NaN
# 4  Ferrari     8.0
# 5  Bugatti    14.0
# 6     None    17.0

# %%
# None ga nisbattan tekshiramiz
df_missing.isnull()
# Out:
#     cars  counts
# 0  False   False
# 1  False   False
# 2  False   False
# 3   True    True
# 4  False   False
# 5  False   False
# 6   True   False

# %%
# None holatdagi malumotlarni aniqlaymiz
df_missing.isnull().sum()
# Out:
# cars      2
# counts    1
# dtype: int64

# %%
# dropna method - Missing malumotlardan tozalaymiz

df_clean = df_missing.dropna()
print(df_clean)
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    Volvo     7.0
# 2     Ford     2.0
# 4  Ferrari     8.0
# 5  Bugatti    14.0

# %%
# df_missing.dropna(how="all") # har ikkalasi None bolganini ochiradi
# df_missing.dropna(subset="counts") # tanlangan column None tozalaydi
df_missing.dropna(axis=0) # tanlangan 0-row 1-column None boyicha ochiradi
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    Volvo     7.0
# 2     Ford     2.0
# 4  Ferrari     8.0
# 5  Bugatti    14.0

# %%
# fillna method - ma'lumotlarni tog'irlab toldirib olish

# df_missing.fillna("unknown")
df_missing.fillna({"cars": "unknown", "counts": 0})
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    Volvo     7.0
# 2     Ford     2.0
# 3  unknown     0.0
# 4  Ferrari     8.0
# 5  Bugatti    14.0
# 6  unknown    17.0

# %%
df = pd.read_csv("Titanic-Dataset.csv")

# df.head(100)
df.tail()

# pd.read_excel("Titanic-Dataset.xlsx")
# pd.read_json("Titanic-Dataset.json")
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.to_excel("output.xlsx")

newdf = pd.read_excel("output.xlsx")
newdf.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
# Series => 1D
pd.Series(["BMW", "Tesla", "Bugatti"])
# Out:
# 0        BMW
# 1      Tesla
# 2    Bugatti
# dtype: object
